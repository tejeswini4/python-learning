# %% [markdown]
# <a href="https://colab.research.google.com/github/tejeswini4/python-learning/blob/main/02_If_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Day 2 – if, elif, else
#
# **Date:** 25 July 2026
#
# ## Objective
#
# Learn decision making in Python using:
# - if
# - else
# - elif
#
# Today's Goal:
# - Write 15 Python programs using decision making.

# %% [markdown]
# # Program 1: Even or Odd

# %%
number = int(input("Enter a number: "))
if number  % 2 == 0:
    print("number is even")
else:
    print("number is odd")
# Out:
# Enter a number: 5
# number is odd

# %% [markdown]
# prog 2 :positive,neg,or zero

# %%
number = int(input("Enter a number: "))

if number > 0:
  print("number is positive")
elif number < 0:
  print("number is negative")
else :
  print("number is zero")
# Out:
# Enter a number: 65
# number is positive

# %% [markdown]
# program 3 vote eligbility

# %%
age = int(input("Enter the age: "))

if age >= 18:
  print("Elligible to vote ")
else:
  print("Not eligible to vote")
# Out:
# Enter the age: 12
# Not eligible to vote

# %% [markdown]
# program 4 large number

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the scecod number: "))

if first_number  > second_number:
  print("large", first_number)
elif first_number  < second_number:
  print("large", second_number )
else :
   print("both are equal")
# Out:
# Enter the first number: 5
# Enter the scecod number: 5
# both are equal

# %% [markdown]
# program 5 : largest of three numbers

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the second number :"))
third_number = int(input("Enter the third number: "))

if first_number > second_number and first_number > third_number:
  print("largest number ", first_number)
elif second_number > first_number and second_number > third_number:
  print("largest number ", second_number)
else:
  print("largest number ",third_number)
# Out:
# Enter the first number: 456
# Enter the second number :425
# Enter the third number: 123
# largest number  456

# %% [markdown]
# program 6 : leap year

# %%
year = int(input("Enter the year: "))

if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
  print("leap year")
else :
  print("not a leap year")
# Out:
# Enter the year: 2000
# leap year

# %% [markdown]
# program 7 : grade calculator

# %%
marks = int(input("Enter the marks: "))

if marks >= 90:
  print("GRADE A")
elif marks >= 80 and marks <= 89:
  print("GRADE B")
elif marks >=70 and marks <= 79:
  print("GRADE C")
elif marks >= 60 and marks <= 69:
  print("GRADE D")
else:
  print("GRADE Fail")
# Out:
# Enter the marks: 75
# GRADE C

# %% [markdown]
# program 8 : divisible by 5 and 11

# %%
number = int(input("Entera number: "))

if number % 5 == 0 and number % 11 ==0:
  print("divisible by both 5 and 11")
else:
  print("not divisible by both 5 and 11")
# Out:
# Entera number: 220
# divisible by both 5 and 11

# %% [markdown]
# program 9 : vowel and consonant

# %%
letter = input("Enter a letter: ")

if letter == "a" or letter == "e" or letter == "i" or letter == "o" or letter == "u" or letter == "A" or letter == "E" or letter == "I" or letter == "O" or letter == "U":
  print("vowel")
else:
  print("consonant")
# Out:
# Enter a letter: a
# vowel

# %%
letter = input("Enter a letter: ").lower()

if letter in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a letter: A
# Vowel

# %% [markdown]
#   # program 10: character type checker

# %%
character = input("Enter a character: ")

if character.isalpha():
  print("alphabet")
elif character.isdigit():
  print("digit")
else:
  print("special character")
# Out:
# Enter a character: g
# alphabet

# %% [markdown]
# # program 11: number is divisible by 3 or 7

# %%
number = int(input("Enter a number: "))

if number % 3 == 0 and number % 7 == 0:
    print("Divisible by both 3 and 7")
elif number % 3 == 0:
    print("Divisible by 3")
elif number % 7 == 0:
    print("Divisible by 7")
else:
    print("Not divisible by 3 or 7")
# Out:
# Enter a number: 21
# Divisible by both 3 and 7

# %% [markdown]
# # program 12 : smallest of two numbers

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the second number: "))

if first_number < second_number:
  print("smallest number", first_number)
elif first_number > second_number:
  print("smallest number", second_number)
else :
  print("both are equal")
# Out:
# Enter the first number: 45
# Enter the second number: 78
# smallest number 45

# %% [markdown]
# # program 13 : positive odd or positive even

# %%
number = int(input("Enter a number: "))

if number > 0:
    if number % 2 == 0:
        print("Positive Even")
    else:
        print("Positive Odd")
elif number < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number: 63
# Positive Odd

# %% [markdown]
# # program 14 : simple calculator

# %%
first_number = int(input("Enter the 1st number: "))
second_number = int(input("Enter the 2nd number: "))
operator = input("enter the operator: ")

if operator == "+":
    print("Addition =", first_number + second_number)
elif operator == "-":
    print("Subtraction =", first_number - second_number)
elif operator == "*":
    print("Multiplication =", first_number * second_number)
elif operator == "/":
    if second_number != 0:
        print("Division =", first_number / second_number)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Enter the 1st number: 14
# Enter the 2nd number: 0
# enter the operator: /
# Cannot divide by zero

# %% [markdown]
# # program 15 : largest among four numbers

# %%
a = int(input("Enter the 1st number: "))
b = int(input("Enter the 2nd number: "))
c = int(input("Enter the 3rd number: "))
d = int(input("Enter the 4th number: "))

if a >= b and a >= c and a >= d:
  print("a is largest")
elif  b >= c and b >= d and b >= a:
    print("b is largest")
elif c >= d and c >= a and c >= b:
      print("c is largest")
else:
      print("d is largest")
# Out:
# Enter the 1st number: 4
# Enter the 2nd number: 3
# Enter the 3rd number: 85
# Enter the 4th number: 145
# d is largest

# %% [markdown]
# # Day 2 Summary
#
# ## Topics Learned
# - if
# - else
# - elif
# - Comparison operators
# - Modulus operator
#
# ## Programs Completed
# - 15 decision-making programs
#
# ## What I Learned
# Today I learned how Python makes decisions based on conditions.
