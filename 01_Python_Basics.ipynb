# %% [markdown]
# <a href="https://colab.research.google.com/github/tejeswini4/python-learning/blob/main/01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Learning 🐍
#
# This repository documents my Python learning journey as I prepare for a Master's in AI/ML in Germany.
#
# ## Progress
#
# ### Day 1
# - ✅ Print statements
# - ✅ Variables
# - ✅ User Input
# - ✅ Arithmetic Operators
# - ✅ 15 Python Programs
#
# ## Goal
# Build a strong Python foundation before moving to Data Science, Machine Learning, and Deep Learning.

# %% [markdown]
# # Print statements

# %%
print("Hello AI World")
print("I am learning python")
print("My goal is AI, Data Science and Robotics")
# Out:
# Hello AI World
# I am learning python
# My goal is AI, Data Science and Robotics

# %% [markdown]
# # Variables

# %%
name = "Tejeswini"
branch = "Artifical Intelligence and Machine Learning"
cgpa = 6.72

print(name)
print(branch)
print(cgpa)
# Out:
# Tejeswini
# Artifical Intelligence and Machine Learning
# 6.72

# %% [markdown]
# #Create your AI profile

# %%
name = "Tejeswini"
skills = ["Python", "AI", "Machine Learning", "Data Science"]
goal = "Masters in Germany"

print(name)
print(skills)
print(goal)
# Out:
# Tejeswini
# ['Python', 'AI', 'Machine Learning', 'Data Science']
# Masters in Germany

# %% [markdown]
# #prog 1

# %%
#print my name
print("Tejeswini")
# Out:
# Tejeswini

# %% [markdown]
# #prog 2

# %%
#print my college name
print("Mangalore Institute of Technology and Engineering")
# Out:
# Mangalore Institute of Technology and Engineering

# %% [markdown]
# #prog 3

# %%
#print your goal
print("My goal is to pursue masters in Germany")
# Out:
# My goal is to pursue masters in Germany

# %% [markdown]
# #prog 4

# %%
#variables
name = "Tejeswini"
branch = "Artifical Intelligence and Machine Learning"
cgpa = 6.72

print(name)
print(branch)
print(cgpa)
# Out:
# Tejeswini
# Artifical Intelligence and Machine Learning
# 6.72

# %% [markdown]
# #prog 5

# %%
name = input("Enter your name:")
age = int(input("Enter your age :"))

print("Name:",name)
print("Age:",age)
# Out:
# Enter your name:Teju
# Enter your age :21
# Name: Teju
# Age: 21

# %% [markdown]
# #example

# %%
name = input("Enter your name;")
age = int(input("Enter your age:"))
cgpa = float(input("Enter your cgpa"))

print("student details")
print("Name:",name)
print("Age:",age)
print("CGPA:",cgpa)
# Out:
# Enter your name;Tej
# Enter your age:21
# Enter your cgpa6.72
# student details
# Name: Tej
# Age: 21
# CGPA: 6.72

# %% [markdown]
# #prog 6

# %%
a = int(input("Enter 1st number:"))
b = int(input("Enter 2nd number:"))

print("sum:", a+b)
# Out:
# Enter 1st number:3
# Enter 2nd number:9
# sum: 12

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the second number: "))

sum_result = first_number + second_number

print("Sum:", sum_result)
# Out:
# Enter the first number: 5
# Enter the second number: 45
# Sum: 50

# %% [markdown]
# #prog 7

# %%
#Basic calculator

a = int(input("Enter 1st number:"))
b = int(input("Enter 2nd number:"))

print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
# Out:
# Enter 1st number:5
# Enter 2nd number:2
# Addition: 7
# Subtraction: 3
# Multiplication: 10
# Division: 2.5

# %%
first_number = int(input("Enter the first number: "))
second_number = int(input("Enter the second number: "))

print("Addition:", first_number + second_number)
print("Subtraction:", first_number - second_number)
print("Multiplication:", first_number * second_number)
print("Division:", first_number / second_number)
# Out:
# Enter the first number: 2
# Enter the second number: 4
# Addition: 6
# Subtraction: -2
# Multiplication: 8
# Division: 0.5

# %% [markdown]
# #prog 8

# %%
#Area of rectangle

Length = int(input("Enter the length:"))
Breadth = int(input("Enter the breadth:"))

Area = Length * Breadth

print("Area:", Area)
# Out:
# Enter the length:5
# Enter the breadth:10
# Area: 50

# %% [markdown]
# #prog 9

# %%
#Area of circle

radius = float(input("Enter the radius:"))

pi = 3.14159

area = pi*radius*radius

print("Area_of_circle:",area)
# Out:
# Enter the radius:2.5
# Area_of_circle: 19.6349375

# %% [markdown]
# # prog 10

# %%
#swap two variables using third variable

first_number = int(input("Enter the first number:"))
second_number = int(input("Enter the second number:"))

temp = first_number
first_number = second_number
second_number = temp

print("after swapping:")
print("First number:", second_number)
print("Second number:", first_number)
# Out:
# Enter the first number:10
# Enter the second number:20
# after swapping:
# First number: 10
# Second number: 20

# %%
#swapping without third variable

first_number = int(input("Enter the first number:"))
second_number = int(input("Enter the second number:"))

first_number , second_number = second_number, first_number

print("after swapping:")
print("First number:",first_number)
print("second_number:",second_number)
# Out:
# Enter the first number:12
# Enter the second number:10
# after swapping:
# First number: 10
# second_number: 12

# %% [markdown]
# # ex 1

# %%
#square of number

number = int(input("Enter your number:"))

square = number ** 2
print("square of number:",square)
# Out:
# Enter your number:3
# square of number: 9

# %% [markdown]
# #ex 2

# %%
#cube of number

number = int(input("Enter your number:"))

cube = number ** 3
print("cube of number:",cube)
# Out:
# Enter your number:3
# cube of number: 27

# %% [markdown]
# #ex 3

# %%
#perimeter of rect

length = int(input("Enter the length: "))
breadth = int(input("Enter the breadth: "))

perimeter = 2 * (length + breadth)

print("perimeter of rectangle:",perimeter)
# Out:
# Enter the length: 2
# Enter the breadth: 6
# perimeter of rectangle: 16

# %% [markdown]
# #ex 4

# %%
#celsius to fahrenheit

celsius = float(input("Enter the temperature in celsius: "))

fahrenheit = (9/5) * celsius + 32

print("celsius to fahrenheit: ", fahrenheit)
# Out:
# Enter the temperature in celsius: 35
# celsius to fahrenheit:  95.0

# %% [markdown]
# #ex 5

# %%
#fahrenheit to celsius
fahrenheit = float(input("Enter the temperature in fahrenheit: "))

celsius = (fahrenheit - 32) * (5/9)

print("fahrenheit to celsius: ",celsius)
# Out:
# Enter the temperature in fahrenheit: 25
# fahrenheit to celsius:  -3.8888888888888893
